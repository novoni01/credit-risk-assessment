# %%
import data_ingestion_kaggle

# %%
#get kaggle information necessary to download csv
data_ingestion_kaggle.move_kaggle_json()

proper_directory = data_ingestion_kaggle.initialize_data_path()
# Out:
# Kaggle json already exists in user

# %%
#Retrieve Kaggle datasets
kaggle_df_list = data_ingestion_kaggle.retrieve_training_csv(proper_directory)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/wordsforthewise/lending-club
# c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\accepted_2007_to_2018q4.csv is folder or dir
# c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\rejected_2007_to_2018q4.csv is folder or dir
# c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\accepted_2007_to_2018q4.csv\accepted_2007_to_2018Q4.csv is a file
# c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\rejected_2007_to_2018q4.csv\rejected_2007_to_2018Q4.csv is a file

# %%
#Get the Kaggle Accepted DF cleaned up
kaggle_accepted_df = data_ingestion_kaggle.kaggle_accepted_loans_df(kaggle_df_list)
kaggle_rejected_df = data_ingestion_kaggle.kaggle_rejected_loans_df(kaggle_df_list)
# Out:
# replacing Amount Requested with median float
# replacing Application Date na's with most repeated string
# replacing Loan Title na's with most repeated string
# replacing Debt-To-Income Ratio na's with most repeated string

# %%
kaggle_accepted_df.head(10)
# Out:
#                 id  loan_amnt  funded_amnt  term_months  int_rate  \
# 238242    53212169    20000.0      20000.0           36      7.26
# 1751556   10178897     5000.0       5000.0           36      7.90
# 313634    46427043     9500.0       9500.0           36      5.93
# 1578115  132044747    16000.0      16000.0           36      5.31
# 1301224   13418070     5000.0       5000.0           36      6.03
# 53172     65812174    18000.0      18000.0           60     13.67
# 407251    38609512    23700.0      23700.0           36     14.99
# 626090   112433449    30000.0      30000.0           36      7.97
# 1950945   90304966    26800.0      26800.0           36     25.69
# 2217049   92588241     3300.0       3300.0           36      8.24
#
#          installment  annual_inc    dti  delinq_2yrs  fico_range_low  ...  \
# 238242        619.93     99000.0  13.79          0.0           730.0  ...
# 1751556       156.46     35000.0  14.03          0.0           725.0  ...
# 313634        288.71     75000.0  20.35          0.0           700.0  ...
# 1578115       481.77     40000.0  36.85          0.0           730.0  ...
# 1301224       152.18     87000.0  11.09          0.0           765.0  ...
# 53172         415.76     70000.0  16.42          0.0           700.0  ...
# 407251        821.46     54000.0  39.04          0.0           660.0  ...
# 626090        939.68    120000.0  20.56          1.0           700.0  ...
# 1950945      1075.37     67000.0  15.19          0.0           745.0  ...
# 2217049       103.78     60000.0  14.16          1.0           685.0  ...
#
#          open_acc  revol_bal  revol_util  total_acc  pub_rec_bankruptcies  \
# 238242       11.0    27791.0        64.3       21.0                   0.0
# 1751556      11.0     4087.0        14.1       30.0                   1.0
# 313634       15.0     9845.0        27.6       36.0                   1.0
# 1578115      18.0    27210.0        31.8       29.0                   0.0
# 1301224      18.0     4519.0         8.2       41.0                   0.0
# 53172         9.0    14407.0        76.6       11.0                   0.0
# 407251       15.0    50740.0        77.3       25.0                   0.0
# 626090       11.0     8980.0        33.5       20.0                   1.0
# 1950945       9.0     7220.0        19.8       11.0                   0.0
# 2217049      14.0     7456.0        20.2       25.0                   1.0
#
#          home_ownership  loan_status             purpose application_type  \
# 238242         MORTGAGE   Fully Paid         credit_card       Individual
# 1751556        MORTGAGE   Fully Paid         credit_card       Individual
# 313634             RENT   Fully Paid         credit_card       Individual
# 1578115        MORTGAGE      Current         credit_card       Individual
# 1301224        MORTGAGE   Fully Paid         credit_card       Individual
# 53172              RENT   Fully Paid  debt_consolidation       Individual
# 407251              OWN   Fully Paid  debt_consolidation       Individual
# 626090         MORTGAGE      Current  debt_consolidation        Joint App
# 1950945            RENT  Charged Off    home_improvement       Individual
# 2217049            RENT      Current  debt_consolidation       Individual
#
#         verification_status
# 238242      Source Verified
# 1751556        Not Verified
# 313634      Source Verified
# 1578115     Source Verified
# 1301224     Source Verified
# 53172              Verified
# 407251             Verified
# 626090             Verified
# 1950945     Source Verified
# 2217049     Source Verified
#
# [10 rows x 22 columns]

# %%
kaggle_rejected_df.head(10)
# Out:
#           Amount Requested Application Date               Loan Title  \
# 15574570           15000.0       2018-10-31  Credit card refinancing
# 3923247             2500.0       2017-02-28                    other
# 14693421           40000.0       2018-10-01       Debt consolidation
# 17679301            5000.0       2018-04-18  Credit card refinancing
# 14825204            2500.0       2018-10-05       Debt consolidation
# 10114387           10000.0       2018-01-21       Debt consolidation
# 26629531           15000.0       2016-10-27       Debt consolidation
# 17458701           25000.0       2018-04-10  Credit card refinancing
# 22516874           35000.0       2015-05-05              credit_card
# 11829501            2000.0       2017-07-14       Debt consolidation
#
#          Debt-To-Income Ratio
# 15574570               39.01%
# 3923247                10.77%
# 14693421               24.13%
# 17679301                19.3%
# 14825204               10.66%
# 10114387               27.94%
# 26629531               31.97%
# 17458701               15.87%
# 22516874               34.59%
# 11829501                56.1%

# %%
hdma_accepted_df = data_ingestion_kaggle.clean_hdma_accepted(proper_directory)
hdma_accepted_df.head(10)
# Out:
#    activity_year  action_taken  preapproval  loan_purpose  loan_amount  \
# 0           2023             1            2             1        75000
# 1           2023             1            2             1       445000
# 2           2023             1            2             1       145000
# 3           2023             1            2             1       425000
# 4           2023             1            2             1       425000
# 5           2023             1            2             1       325000
# 6           2023             1            2             1       305000
# 7           2023             1            1             1       175000
# 8           2023             1            2             1       125000
# 9           2023             1            2             1       275000
#
#    loan_term  loan_to_value_ratio  income  debt_to_income_ratio  \
# 0        360               80.000   180.0                  44.0
# 1        360               84.000   153.0                  37.0
# 2        360               96.500    73.0                  42.0
# 3        360               75.000    75.0                  46.0
# 4        360              100.880    84.0                  49.0
# 5        360               80.000   189.0                  32.5
# 6        360               95.000    65.0                  46.0
# 7        360              100.000    61.0                  44.0
# 8        360               50.000   132.0                  24.5
# 9        360               87.869   100.0                  39.0
#
#   derived_loan_product_type  applicant_credit_score_type  \
# 0   Conventional:First Lien                            3
# 1   Conventional:First Lien                            1
# 2            FHA:First Lien                            2
# 3   Conventional:First Lien                            2
# 4   Conventional:First Lien                            2
# 5   Conventional:First Lien                            3
# 6            FHA:First Lien                            3
# 7            FHA:First Lien                            1
# 8   Conventional:First Lien                            3
# 9            FHA:First Lien                            3
#
#    co-applicant_credit_score_type  denial_reason-1
# 0                              10               10
# 1                               9               10
# 2                              10               10
# 3                               9               10
# 4                               9               10
# 5                              10               10
# 6                              10               10
# 7                              10               10
# 8                               9               10
# 9                               9               10

# %%
hdma_rejected_df = data_ingestion_kaggle.clean_hdma_rejected(proper_directory)
hdma_rejected_df.head(10)
# Out:
#    activity_year  action_taken  preapproval  loan_purpose  loan_amount  \
# 0           2023             3            2             1       545000
# 1           2023             3            2             1       315000
# 2           2023             3            2             1       255000
# 3           2023             3            2             1       425000
# 4           2023             3            2            32       425000
# 5           2023             3            2            32       215000
# 6           2023             3            2             1       245000
# 7           2023             3            2            32       565000
# 8           2023             3            2             1       415000
# 9           2023             3            2            32       365000
#
#    loan_term  loan_to_value_ratio  income  debt_to_income_ratio  \
# 0        360               80.000   110.0                  55.0
# 1        360               98.974    65.0                  55.0
# 2        360               96.500    39.0                  60.0
# 3        360               90.000    85.0                  60.0
# 4        360               78.879   158.0                  32.5
# 5        360               84.706    92.0                  60.0
# 6        360               96.500    48.0                  55.0
# 7        360               76.087   134.0                  55.0
# 8        360               75.000   177.0                  55.0
# 9        360               40.782    47.0                  60.0
#
#   derived_loan_product_type  applicant_credit_score_type  \
# 0   Conventional:First Lien                            2
# 1            FHA:First Lien                            3
# 2            FHA:First Lien                            2
# 3   Conventional:First Lien                            2
# 4            FHA:First Lien                            1
# 5             VA:First Lien                            3
# 6            FHA:First Lien                            1
# 7            FHA:First Lien                            1
# 8   Conventional:First Lien                            3
# 9   Conventional:First Lien                            2
#
#    co-applicant_credit_score_type  denial_reason-1
# 0                               9                1
# 1                               9                4
# 2                              10                1
# 3                               9                1
# 4                               9                1
# 5                              10                1
# 6                              10                1
# 7                               9                3
# 8                               9                1
# 9                              10                1

# %%
#Delete all big files (kaggle datasets in particular) to safely upload code to github
data_ingestion_kaggle.delete_large_files(proper_directory)
# Out:
# size of c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\accepted_2007_to_2018q4.csv is 1675.13381
# deleting c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\accepted_2007_to_2018q4.csv
# size of c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\rejected_2007_to_2018q4.csv is 1782.28162
# deleting c:\Users\Saul\Desktop\Credit Risk Assessment\credit-risk-assessment\ETL\training_data\rejected_2007_to_2018q4.csv
